# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV
import pandas as pd
import pyarrow.parquet as pq
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, root_mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df_final = pd.read_parquet(r'C:\Users\ekait\Git\DSC288R_Capstone\data\final\test_data.parquet')

# %%
df_final
# Out:
#         FlightDate  DayOfWeek  Month   Airline    Origin      Dest  \
# 0       2019-04-01          1      4  0.571737  0.582229  0.514405
# 1       2019-02-27          3      2  0.502162  0.499712  0.497368
# 2       2022-03-10          4      3  0.514854  0.499712  0.493692
# 3       2020-02-29          6      2  0.515570  0.551059  0.546913
# 4       2019-07-25          4      7  0.514854  0.480342  0.461364
# ...            ...        ...    ...       ...       ...       ...
# 1526291 2021-07-19          1      7  0.421375  0.527899  0.558872
# 1526292 2019-11-27          3     11  0.515570  0.551059  0.495967
# 1526293 2019-08-27          2      8  0.618702  0.480888  0.551761
# 1526294 2021-11-12          5     11  0.571737  0.465429  0.525933
# 1526295 2019-03-06          3      3  0.458942  0.466242  0.495967
#
#          CRSDepTime  CRSArrTime  AirTime  Distance  ...  weekly_avg_dest_snow  \
# 0               945        1500    176.0    1491.0  ...              0.000000
# ...

# %%
import kaggle
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import kaggle
#
# File c:\Users\ekait\anaconda3\envs\DSC288R_Capstone\Lib\site-packages\kaggle\__init__.py:7
#       4 from kaggle.api_client import ApiClient
#       6 api = KaggleApi(ApiClient())
# ----> 7 api.authenticate()
#
# File c:\Users\ekait\anaconda3\envs\DSC288R_Capstone\Lib\site-packages\kaggle\api\kaggle_api_extended.py:407, in KaggleApi.authenticate(self)
#     405         return
#     406     else:
# --> 407         raise IOError('Could not find {}. Make sure it\'s located in'
#     408                       ' {}. Or use the environment method. See setup'
#     409                       ' instructions at'
#     410                       ' https://github.com/Kaggle/kaggle-api/'.format(
#     411                           self.config_file, self.config_dir))
# ...

# %%
import os

# Check the current working directory
print("Current Working Directory:", os.getcwd())

# List files in the root directory
print("\nFiles in Root Directory (/):", os.listdir("/"))

# Get the user's home directory
home_dir = os.path.expanduser("~")
print("\nUser Home Directory:", home_dir)
print("Files in Home Directory:", os.listdir(home_dir))

# List files in the current working directory
print("\nFiles in Current Working Directory:", os.listdir(os.getcwd()))
# Out:
# Current Working Directory: /home/ekrichards/private/DSC288R_Capstone/notebooks
#
# Files in Root Directory (/): ['bin', 'boot', 'dev', 'etc', 'home', 'lib', 'lib32', 'lib64', 'libx32', 'media', 'mnt', 'opt', 'proc', 'root', 'run', 'sbin', 'srv', 'sys', 'tmp', 'usr', 'var', 'datasets', 'datasets-3', 'datasets-2', 'run_jupyter.sh']
#
# User Home Directory: /home/ekrichards
# Files in Home Directory: ['public', '.conda', 'teams', '.ipython', '.local', '.nv', '.git-credential-cache', '.cache', '.npm', '.bash_history', 'private', '.jupyter', '.config']
#
# Files in Current Working Directory: ['sr.ipynb', 'er_EDA.ipynb', 'km_modeling_2_updated.ipynb', '.ipynb_checkpoints', 'tester.ipynb', 'Kian_EDA (1).ipynb', 'er_model_testing.ipynb']

# %%
import os
for key, value in os.environ.items():
    print(f"{key}: {value}")
# Out:
# SHELL: /bin/bash
# KUBERNETES_SERVICE_PORT_HTTPS: 443
# NVIDIA_VISIBLE_DEVICES: MIG-1243cb23-1073-5317-bd8d-46de18240b6c
# JUPYTERHUB_ADMIN_ACCESS: 1
# KUBERNETES_SERVICE_PORT: 443
# NSS_WRAPPER_GROUP: /tmp/group.wrap
# CONDA_EXE: /opt/conda/bin/conda
# _CE_M:
# JUPYTERHUB_SERVICE_URL: http://0.0.0.0:8888/user/ekrichards/
# HOSTNAME: dsmlp-jupyter-ekrichards
# LANGUAGE: C.UTF-8
# JUPYTERHUB_API_TOKEN: 6cdf1201d1f944ac809ff6c1aed01322
# _START_SH_EXECUTED: 1
# JUPYTERHUB_BASE_URL: /
# NB_UID: 1000
# NSS_WRAPPER_PASSWD: /tmp/passwd.wrap
# JULIA_PKGDIR: /opt/julia
# MEM_LIMIT: 34359738368
# NB_UMASK: 0002
# XML_CATALOG_FILES: file:///opt/conda/etc/xml/catalog file:///etc/xml/catalog
# PWD: /home/ekrichards
# GSETTINGS_SCHEMA_DIR: /opt/conda/share/glib-2.0/schemas
# LOGNAME: ekrichards
# CONDA_PREFIX: /opt/conda
# MEM_GUARANTEE: 17179869184
# GSETTINGS_SCHEMA_DIR_CONDA_BACKUP:
# JUPYTER_IMAGE: ghcr.io/ucsd-ets/scipy-ml-notebook:2025.1-stable
# RSTUDIO_WHICH_R: /opt/conda/bin/R
# ...
